# %% [markdown]
# # Problem 3

# %%
# !pip install gudhi
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\asaf0\anaconda3\lib\site-packages)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
import gudhi as gd

# Define the 8 points on the unit circle
theta = np.linspace(0, 2*np.pi, 8, endpoint=False)
points = np.column_stack((np.cos(theta), np.sin(theta)))

# Calculate the pairwise distances
distance_matrix = squareform(pdist(points))

# Create a Rips complex and compute the persistence
rips_complex = gd.RipsComplex(distance_matrix=distance_matrix, max_edge_length=2)
simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
persistence = simplex_tree.persistence()

# Plot the persistence barcodes
gd.plot_persistence_barcode(persistence)
plt.show()

# Plot the persistence diagram
gd.plot_persistence_diagram(persistence)
plt.show()
# Out:
# usetex mode requires ghostscript.
